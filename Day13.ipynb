# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashanth-557/ML-Training/blob/main/Day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
claim_data = pd.read_csv(r'C:\Users\akhil\Downloads\Ifood_new.csv')
claim_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cf9da8dd7b08> in <cell line: 0>()
# ----> 1 claim_data = pd.read_csv(r'C:\Users\akhil\Downloads\Ifood_new.csv')
#       2 claim_data.head()
#
# ...

# %%
df=sns.load_dataset('taxis')
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
sns.barplot(x='payment',y='total',data=df,color='red',estimator='median')#std,median
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df['fare'],color='blue')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],palette=['blue','yellow'],hue=df['payment'])
plt.show()

# %%
sns.boxplot(x=df['total'],color='Darkgreen')
# Out:
# <Axes: xlabel='total'>

# %%
a=sns.load_dataset('iris')
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=a['sepal_length'],color='red')
# Out:
# <Axes: xlabel='sepal_length'>

# %%
lower= q1 - 1.5(q3-q1)
upper= q3 + 1.5(q3-q1)

# %%
sns.boxplot(x=a['petal_length'],color='blue')
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.displot(x=a['petal_length'],color='green')

# %%
sns.distplot(x=df['fare'],hist=False,color='Black',kde=True)
plt.show()

# %%
sns.distplot(x=df['fare'],hist=True,color='Black',kde=True)
plt.show()

# %%
sns.distplot(x=df['fare'],hist=False,color='Black',kde=False)
plt.show()

# %%
sns.boxplot(x=a['sepal_width'],palette=['violet','red','lightgreen'],y=a['species'])
plt.show()

# %%
sns.scatterplot(x=df['fare'],y=df['tip'],palette=['yellow','red'])
plt.show()

# %%
sns.scatterplot(x=df['fare'],y=df['tip'],palette=['yellow','red'],hue=df['payment'])
plt.show()

# %%
sns.scatterplot(x=df['fare'],y=df['total'],palette=['blue','yellow'],hue=df['payment'])
plt.show()

# %%
sns.stripplot(x=df['fare'],y=df['color'],palette=['blue','yellow'])
plt.show()

# %%
sns.swarmplot(x=df['fare'],y=df['payment'],palette=['blue','yellow'],hue=df['color'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-7e9a6116740a> in <cell line: 0>()
# ----> 1 sns.swarmplot(x=df['fare'],y=df['payment'],palette=['blue','yellow'],hue=df['color'])
#       2 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2248     ))
#    2249
# -> 2250     p.plot_swarms(
#    2251         dodge=dodge,
#    2252         color=color,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in plot_swarms(self, dodge, color, warn_thresh, plot_kws)
#     586                 points.draw = draw.__get__(points)
#     587
# --> 588         _draw_figure(ax.figure)
# ...

# %%
sns.lineplot(x=df['total'],y=df['fare'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['black','orange'])
plt.show()

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'])
plt.show()

# %%
sns.countplot(x=df['fare'])
plt.show()
